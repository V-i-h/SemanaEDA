# %% [markdown]
# Music IA Education

# %% [markdown]
# # Coleta de Dados
#
# * Questionário via Google Forms
# * Perguntas sobre a faixa etária, professor e estilo musical

# %% [markdown]
# # Objetivo do Experimento
#
# * Criar musicas com ritmos e estilos musicais adequados para uma turma especifica.
# * As musicas  tem  o objetivo  de auxiliar o professor com recurso didático, sendo que as letras das canções abordarão o conteúdo ministrado pelo professor.
# * As músicas serão geradas por IA no software SUNO e disponibilizado em forma de link.

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/pesquisamusicalv2.csv')

# %%
df
# Out:
#    Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0   21/08/2024 10:03:25                                  3
# 1   21/08/2024 10:04:39                                  5
# 2   21/08/2024 10:04:52                                  1
# 3   21/08/2024 10:04:53                                  1
# 4   21/08/2024 10:04:55                                  5
# ..                  ...                                ...
# 90  22/08/2024 10:31:40                                  3
# 91  22/08/2024 10:31:45                                  1
# 92  22/08/2024 10:38:10                                  1
# 93  22/08/2024 10:39:06                                  5
# 94  22/08/2024 10:40:15                                  5
#
#     Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                      1                                 1
# 1                                      3                                 5
# ...

# %%
df.columns=['data','rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica','professor','faixa_etaria']

# %%
df
# Out:
#                    data  rock  hiphop  mpb  reggae  funk  sertanejo  gospel  \
# 0   21/08/2024 10:03:25     3       1    1       1     1          1       1
# 1   21/08/2024 10:04:39     5       3    5       2     1          3       1
# 2   21/08/2024 10:04:52     1       5    1       1     1          1       1
# 3   21/08/2024 10:04:53     1       5    4       4     4          1       1
# 4   21/08/2024 10:04:55     5       4    3       4     1          1       2
# ..                  ...   ...     ...  ...     ...   ...        ...     ...
# 90  22/08/2024 10:31:40     3       4    2       2     3          4       1
# 91  22/08/2024 10:31:45     1       1    1       1     1          1       1
# 92  22/08/2024 10:38:10     1       1    5       1     1          1       5
# 93  22/08/2024 10:39:06     5       2    4       2     1          4       1
# 94  22/08/2024 10:40:15     5       5    5       5     5          5       5
#
#     eletronica professor faixa_etaria
# ...

# %%
df = df.drop(columns='data')

# %%
df
# Out:
#     rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica professor  \
# 0      3       1    1       1     1          1       1           3       NaN
# 1      5       3    5       2     1          3       1           5       NaN
# 2      1       5    1       1     1          1       1           5       NaN
# 3      1       5    4       4     4          1       1           5       NaN
# 4      5       4    3       4     1          1       2           5       NaN
# ..   ...     ...  ...     ...   ...        ...     ...         ...       ...
# 90     3       4    2       2     3          4       1           4    Victor
# 91     1       1    1       1     1          1       1           1    Victor
# 92     1       1    5       1     1          1       5           1    Victor
# 93     5       2    4       2     1          4       1           5    Victor
# 94     5       5    5       5     5          5       5           5   Luciano
#
#    faixa_etaria
# 0           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rock          95 non-null     int64
#  1   hiphop        95 non-null     int64
#  2   mpb           95 non-null     int64
#  3   reggae        95 non-null     int64
#  4   funk          95 non-null     int64
#  5   sertanejo     95 non-null     int64
#  6   gospel        95 non-null     int64
#  7   eletronica    95 non-null     int64
#  8   professor     57 non-null     object
#  9   faixa_etaria  57 non-null     object
# dtypes: int64(8), object(2)
# memory usage: 7.6+ KB

# %%
df.describe()
# Out:
#             rock     hiphop        mpb     reggae       funk  sertanejo  \
# count  95.000000  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    3.263158   3.084211   3.242105   2.578947   2.431579   2.884211
# std     1.545140   1.534450   1.396925   1.411043   1.492197   1.457652
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     2.000000   1.500000   2.000000   1.000000   1.000000   1.500000
# 50%     4.000000   3.000000   4.000000   2.000000   2.000000   3.000000
# 75%     5.000000   4.500000   4.000000   3.500000   4.000000   4.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#           gospel  eletronica
# count  95.000000   95.000000
# mean    2.652632    3.189474
# std     1.493022    1.573009
# min     1.000000    1.000000
# 25%     1.000000    1.000000
# 50%     2.000000    4.000000
# 75%     4.000000    5.000000
# max     5.000000    5.000000
