# %% [markdown]
# Pesquisa: Música
#
# * Rock
# * Hip Hop
# * Rap
# * Mpb
# * Reggae
# * Funk
# * Sertanejo
# * Gospel
# * Eletrônica

# %%
import pandas as pd

# %%
df_pesquisa = pd.read_csv('datasets/pesquisasimulada.csv')

# %%
df_pesquisa
# Out:
#    Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0   21/08/2024 10:03:25                                  3
# 1   21/08/2024 10:04:39                                  5
# 2   21/08/2024 10:04:52                                  1
# 3   21/08/2024 10:04:53                                  1
# 4   21/08/2024 10:04:55                                  5
# 5   21/08/2024 10:05:26                                  5
# 6   21/08/2024 10:05:41                                  2
# 7   21/08/2024 10:06:14                                  5
# 8   21/08/2024 10:07:16                                  4
# 9   21/08/2024 10:07:26                                  5
# 10  21/08/2024 10:07:31                                  3
# 11  21/08/2024 10:08:37                                  4
# 12  21/08/2024 10:38:46                                  5
# 13  21/08/2024 10:58:52                                  5
#
#     Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# ...

# %%
df_pesquisa.columns=['data','rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica']

# %%
df_pesquisa.drop(columns='data')
# Out:
#     rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0      3       1    1       1     1          1       1           3
# 1      5       3    5       2     1          3       1           5
# 2      1       5    1       1     1          1       1           5
# 3      1       5    4       4     4          1       1           5
# 4      5       4    3       4     1          1       2           5
# 5      5       2    2       2     1          1       2           4
# 6      2       4    4       1     4          4       1           3
# 7      5       3    3       3     1          2       3           4
# 8      4       4    4       1     4          4       1           4
# 9      5       5    1       3     4          1       1           3
# 10     3       2    5       4     3          4       4           2
# 11     4       1    5       1     1          2       5           1
# 12     5       1    3       1     1          1       1           4
# ...

# %%
df_pesquisa.drop(columns='data')
# Out:
#     rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0      3       1    1       1     1          1       1           3
# 1      5       3    5       2     1          3       1           5
# 2      1       5    1       1     1          1       1           5
# 3      1       5    4       4     4          1       1           5
# 4      5       4    3       4     1          1       2           5
# 5      5       2    2       2     1          1       2           4
# 6      2       4    4       1     4          4       1           3
# 7      5       3    3       3     1          2       3           4
# 8      4       4    4       1     4          4       1           4
# 9      5       5    1       3     4          1       1           3
# 10     3       2    5       4     3          4       4           2
# 11     4       1    5       1     1          2       5           1
# 12     5       1    3       1     1          1       1           4
# ...

# %%
df_pesquisa = df_pesquisa.drop(columns='data')

# %%
soma_pontuacoes = df_pesquisa.sum()

# %% [markdown]
# ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
soma_pontuacoes.plot(kind='barh')
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.histplot(df_pesquisa,kde=True,bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(df_pesquisa)
# Out:
# <Axes: >
