# %% [markdown]
# Semana EDA(Exploratory Data Analysis)
#
# * Análise Exploratória de Dados

# %% [markdown]
# ## Problema

# %% [markdown]
# * Uma escola necessita trabalhar com filmes em seu planejamento pedagógico.
# * Precisa visualizar as notas de diversos filmes em suas diversas categorias.
# * Os filmes devem atravessar gerações. A escola trabalha desde a creche até o nível superior.

# %% [markdown]
# ## Ambientação

# %% [markdown]
# * Usamos a linguagem Python (multi,tip.din,ident,bibli,poo)

# %%
mensagem = "Hello, Semana EDA"
print(f'{mensagem}')
msg_input = input("Digite a palavra da semana")
print(msg_input)
# Out:
# Hello, Semana EDA
# aaaa

# %% [markdown]
# ## Competências

# %% [markdown]
# * Importar pandas
# * Ler dados csv
# * Organizar pastas VS CODE
# * Renomear colunas
# * Contar os dados
# * Melhorar a visualização das informações
# * Criar gráficos pandas(plot). Matplotib, Seaborn

# %% [markdown]
# ## Ferramentas e Recursos

# %% [markdown]
# * Jupyter (Visual Code, Anaconda, Jupyter, Google Colab, Azure e AWS)
# * Kaggle (Risco de Crédito) : IA ML Supery.Regressão
# * TrendView
# * MovieLens(opção de 100mil)
# * Python -lambda (Paradigma Funcional)
# * Bibliotecas(Numpy,Pandas, Matplotlib e Seaborn)
# * Gráficos (barras, pizza,dispersão,histograma,boxplot etc)
# * Youtube (População ,Amostra, Frequência,Mediana,Quartis)
# * Estatística Descritiva (frequências e medidas)

# %% [markdown]
# ## Tipos de Variáveis

# %% [markdown]
# ### Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pandas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MySql

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Estatística Descritiva

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Importação do Pandas

# %%
! pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Importação do DataSet

# %%
df = pd.read_csv('datasets/ratings.csv')

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df['movieId']
# Out:
# 0              1
# 1              3
# 2              6
# 3             47
# 4             50
#            ...
# 100831    166534
# 100832    168248
# 100833    168250
# 100834    168252
# 100835    170875
# Name: movieId, Length: 100836, dtype: int64

# %%
df['rating']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64

# %% [markdown]
# ### Renomear as colunas em português

# %%
df.columns = ['usuario_id','filme_id','avaliacao','tempo']

# %%
df.columns
# Out:
# Index(['usuario_id', 'filme_id', 'avaliacao', 'tempo'], dtype='object')

# %% [markdown]
# Mostrando um coluna

# %%
df['avaliacao']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %% [markdown]
# Mostrando uma coluna (+sintática)

# %%
df.avaliacao
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %%
df.avaliacao.value_counts()
# Out:
# avaliacao
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
df.avaliacao.mean()
# Out:
# np.float64(3.501556983616962)

# %%
df.avaliacao.unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %% [markdown]
# Contando histórias com  histogramas

# %%
! pip install matplotlib

# %%
df.avaliacao.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.avaliacao.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: avaliacao, dtype: float64

# %% [markdown]
# Média, Mediana(Q2- Segundo quartil), Soma

# %%
print(f"Imprimindo a média: {df.avaliacao.mean()}")
# Out:
# Imprimindo a média: 3.501556983616962

# %%
print(f"Imprimindo a Mediana: {df.avaliacao.median()}")
# Out:
# Imprimindo a Mediana: 3.5

# %%
print(f"Imprimindo a Soma: {df.avaliacao.sum()}")
# Out:
# Imprimindo a Soma: 353083.0

# %%
! pip install seaborn

# %%
import seaborn as sns

# %%
notas = df.avaliacao
sns.boxplot(notas)
# Out:
# <Axes: ylabel='avaliacao'>

# %%
import pandas as pd

# %% [markdown]
# 1. Ler o dataset movies.csv
# 2. Mostrar os 5 primeiros
# 3. Renomear as colunas para filme_id ,titulo, generos
# 4. Mostrar os 5 primeiros com as colunas renomeadas
#
# Desafio. Mostrar as 5 primeiras avaliações  do Toy Story com as colunas renomeadas.(dica use df.query)

# %%
df_filmes = pd.read_csv('datasets/movies.csv')

# %%
df_filmes.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_filmes.columns=['filme_id','titulo','generos']
df_filmes.columns
# Out:
# Index(['filme_id', 'titulo', 'generos'], dtype='object')

# %%
df_filmes.head(5)
# Out:
#    filme_id                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_filmes.query('titulo == "Toy Story (1995)"').head()
# Out:
#    filme_id            titulo                                      generos
# 0         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
media_por_filme=df.groupby('filme_id').mean()['avaliacao']
media_por_filme.head()
# Out:
# filme_id
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: avaliacao, dtype: float64

# %%
media_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: avaliacao, dtype: float64

# %%
sns.boxplot(x=media_por_filme)
# Out:
# <Axes: xlabel='avaliacao'>

# %%
#kde=True (linha de densidade kernel)- estimativa da função
# bins = 10 - quantos intervalos eu preciso? 
sns.histplot(media_por_filme,kde=True,bins=10)
# Out:
# <Axes: xlabel='avaliacao', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
#plt - refere se sempre matplotlib
plt.hist(media_por_filme)
# Out:
# (array([ 108.,  185.,  309.,  694.,  962., 1840., 2211., 2275.,  798.,
#          342.]),
#  array([0.5 , 0.95, 1.4 , 1.85, 2.3 , 2.75, 3.2 , 3.65, 4.1 , 4.55, 5.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(media_por_filme)
plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')
